# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from math import sqrt
import plotly
import plotly.offline as py
from plotly.offline import plot, iplot
plotly.offline.init_notebook_mode(connected=True)
from yellowbrick.features import FeatureImportances
from pycaret.classification import *
import sqlalchemy
from sqlalchemy import create_engine
import joblib
import plotly.express as px

#biblioteca para lidar com classes desbalanceadas. 
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import NearMiss

# Testes estatísticos
from scipy.stats import chi2_contingency, mannwhitneyu
import scipy.stats as stats

# Modelos de machine learning e utilitários
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split, KFold, cross_val_score, RandomizedSearchCV, cross_validate
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, classification_report, confusion_matrix, make_scorer
from imblearn.under_sampling import NearMiss
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
import category_encoders as ce
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix

# Classificadores e métodos de ensemble
from imblearn.ensemble import BalancedRandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

pd.set_option('display.max_columns', None)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Criando a nossa engine de conexão com o Mysql
engine = sqlalchemy.create_engine('mysql+pymysql://root:airflow@172.17.0.2:3306/Loan_Credit')

# %%
query_local = ''' 
        SELECT *
        FROM local
'''

local = pd.read_sql_query(query_local, engine)

local
# Out:
#             Id                 CITY           STATE
# 0            1                 Rewa  Madhya_Pradesh
# 1            2             Parbhani     Maharashtra
# 2            3            Alappuzha          Kerala
# 3            4          Bhubaneswar          Odisha
# 4            5  Tiruchirappalli[10]      Tamil_Nadu
# ...        ...                  ...             ...
# 251995  251996              Kolkata     West_Bengal
# 251996  251997                 Rewa  Madhya_Pradesh
# 251997  251998      Kalyan-Dombivli     Maharashtra
# 251998  251999          Pondicherry      Puducherry
# 251999  252000                Avadi      Tamil_Nadu
#
# [252000 rows x 3 columns]

# %%
query_profissional = ''' 
        SELECT *
        FROM profissional
'''

profissional = pd.read_sql_query(query_profissional, engine)

profissional
# Out:
#             Id   Income  Experience           Profession  CURRENT_JOB_YRS
# 0            1  1303834           3  Mechanical_engineer                3
# 1            2  7574516          10   Software_Developer                9
# 2            3  3991815           4     Technical_writer                4
# 3            4  6256451           2   Software_Developer                2
# 4            5  5768871          11        Civil_servant                3
# ...        ...      ...         ...                  ...              ...
# 251995  251996  8154883          13              Surgeon                6
# 251996  251997  2843572          10         Army_officer                6
# 251997  251998  4522448           7      Design_Engineer                7
# 251998  251999  6507128           0     Graphic_Designer                0
# 251999  252000  9070230          17         Statistician                7
#
# [252000 rows x 5 columns]

# %%
query_propriedades = ''' 
        SELECT *
        FROM propriedades
'''

propriedades = pd.read_sql_query(query_propriedades, engine)

propriedades
# Out:
#             Id House_Ownership Car_Ownership  CURRENT_HOUSE_YRS
# 0            1          rented            no                 13
# 1            2          rented            no                 13
# 2            3          rented            no                 10
# 3            4          rented           yes                 12
# 4            5          rented            no                 14
# ...        ...             ...           ...                ...
# 251995  251996          rented            no                 11
# 251996  251997          rented            no                 11
# 251997  251998          rented            no                 12
# 251998  251999          rented            no                 10
# 251999  252000          rented            no                 11
#
# [252000 rows x 4 columns]

# %%
query_resposta = ''' 
        SELECT *
        FROM resposta
'''

resposta = pd.read_sql_query(query_resposta, engine)
resposta
# Out:
#             Id  Risk_Flag
# 0            1          0
# 1            2          0
# 2            3          0
# 3            4          1
# 4            5          1
# ...        ...        ...
# 251995  251996          0
# 251996  251997          0
# 251997  251998          0
# 251998  251999          0
# 251999  252000          0
#
# [252000 rows x 2 columns]

# %%
query_usuario = ''' 
        SELECT *
        FROM usuario
'''

usuario = pd.read_sql_query(query_usuario, engine)
usuario
# Out:
#             Id  Age Married/Single
# 0            1   23         single
# 1            2   40         single
# 2            3   66        married
# 3            4   41         single
# 4            5   47         single
# ...        ...  ...            ...
# 251995  251996   43         single
# 251996  251997   26         single
# 251997  251998   46         single
# 251998  251999   45         single
# 251999  252000   70         single
#
# [252000 rows x 3 columns]

# %%
#only process customers with delivered package
df = local.merge(usuario, on = 'Id', how ='inner')
df = df.merge(profissional, on = 'Id')
df = df.merge(propriedades, on = 'Id')
df = df.merge(resposta, on = 'Id')

#Covertendo Rúpias Indianas em Dólar
df['income'] = df['Income'] * 0.012

# Excluir a coluna original 'Income'
df.drop(columns=['Income'], inplace=True)

# %%
del df['Id']
del df['CITY']
del df['STATE']

# %%
dfa = df.copy()

for col in dfa.columns:
    if dfa[col].dtype == 'object':
        dfa[col] = dfa[col].astype('category').cat.codes

dfa
# Out:
#         Age  Married/Single  Experience  Profession  CURRENT_JOB_YRS  \
# 0        23               1           3          33                3
# 1        40               1          10          43                9
# 2        66               0           4          47                4
# 3        41               1           2          43                2
# 4        47               1          11          11                3
# ...     ...             ...         ...         ...              ...
# 251995   43               1          13          45                6
# 251996   26               1          10           3                6
# 251997   46               1           7          17                7
# 251998   45               1           0          27                0
# 251999   70               1          17          44                7
#
#         House_Ownership  Car_Ownership  CURRENT_HOUSE_YRS  Risk_Flag  \
# 0                     2              0                 13          0
# 1                     2              0                 13          0
# 2                     2              0                 10          0
# 3                     2              1                 12          1
# 4                     2              0                 14          1
# ...                 ...            ...                ...        ...
# 251995                2              0                 11          0
# 251996                2              0                 11          0
# 251997                2              0                 12          0
# 251998                2              0                 10          0
# 251999                2              0                 11          0
#
#             income
# 0        15646.008
# 1        90894.192
# 2        47901.780
# 3        75077.412
# 4        69226.452
# ...            ...
# 251995   97858.596
# 251996   34122.864
# 251997   54269.376
# 251998   78085.536
# 251999  108842.760
#
# [252000 rows x 10 columns]

# %%
print(dfa['Married/Single'].value_counts())
print('\n')
print(df['Married/Single'].value_counts())
# Out:
# 1    226272
# 0     25728
# Name: Married/Single, dtype: int64
#
#
# single     226272
# married     25728
# Name: Married/Single, dtype: int64

# %%
print(dfa['House_Ownership'].value_counts())
print('\n')
print(df['House_Ownership'].value_counts())
# Out:
# 2    231898
# 1     12918
# 0      7184
# Name: House_Ownership, dtype: int64
#
#
# rented          231898
# owned            12918
# norent_noown      7184
# Name: House_Ownership, dtype: int64

# %%
print(dfa['Car_Ownership'].value_counts())
print('\n')
print(df['Car_Ownership'].value_counts())
# Out:
# 0    176000
# 1     76000
# Name: Car_Ownership, dtype: int64
#
#
# no     176000
# yes     76000
# Name: Car_Ownership, dtype: int64

# %%
# Criando os DataFrames para as contagens de 'Profession'
df_profession_l = df['Profession'].value_counts().reset_index()
df_profession_l.columns = ['Profession', 'Count']

df_profession_n = dfa['Profession'].value_counts().reset_index()
df_profession_n.columns = ['Profession_Code', 'Count']

# Mapeamento entre profissões originais e códigos
profession_mapping = df[['Profession']].drop_duplicates().reset_index(drop=True)
profession_mapping['Profession_Code'] = profession_mapping['Profession'].astype('category').cat.codes

# Juntando os DataFrames
df_profession_combined = pd.merge(df_profession_l, profession_mapping, on='Profession')

# Exportando para CSV
df_profession_combined.to_csv('profession_mapping.csv', index=False)

# Exibindo o DataFrame combinado
print(df_profession_combined)
# Out:
#                     Profession  Count  Profession_Code
# 0                    Physician   5957               37
# 1                 Statistician   5806               44
# 2                 Web_designer   5397               50
# 3                 Psychologist   5390               40
# 4   Computer_hardware_engineer   5372               13
# 5                      Drafter   5359               19
# 6                   Magistrate   5357               32
# 7             Fashion_Designer   5304               22
# 8       Air_traffic_controller   5281                0
# 9                     Comedian   5259               12
# 10         Industrial_Engineer   5250               29
# 11         Mechanical_engineer   5217               33
# 12           Chemical_engineer   5205                9
# 13            Technical_writer   5195               47
# 14               Hotel_Manager   5178               28
# 15           Financial_Analyst   5167               23
# 16            Graphic_Designer   5166               27
# 17            Flight_attendant   5128               25
# 18         Biomedical_Engineer   5127                6
# 19                   Secretary   5061               42
# 20          Software_Developer   5053               43
# 21          Petroleum_Engineer   5041               36
# 22              Police_officer   5035               38
# 23           Computer_operator   4990               14
# 24                  Politician   4944               39
# 25              Microbiologist   4881               34
# 26                  Technician   4864               48
# 27                      Artist   4861                4
# 28                      Lawyer   4818               30
# 29                  Consultant   4808               15
# 30                     Dentist   4782               16
# 31                   Scientist   4781               41
# 32                     Surgeon   4772               45
# 33                     Aviator   4758                5
# 34       Technology_specialist   4737               49
# 35             Design_Engineer   4729               17
# 36                    Surveyor   4714               46
# 37                   Geologist   4672               26
# 38                     Analyst   4668                1
# 39                Army_officer   4661                3
# 40                   Architect   4657                2
# 41                        Chef   4635                8
# 42                   Librarian   4628               31
# 43              Civil_engineer   4616               10
# 44                    Designer   4598               18
# 45                   Economist   4573               20
# 46                 Firefighter   4507               24
# 47        Chartered_Accountant   4493                7
# 48               Civil_servant   4413               11
# 49                    Official   4087               35
# 50                    Engineer   4048               21

# %%
# Selecionando 30996 amostras da classe 0 com random_state para reprodutibilidade
df_class_0 = df.loc[df['Risk_Flag'] == 0].sample(n=30996, random_state=42)

# Selecionando todos os dados da classe 1
df_class_1 = df.loc[df['Risk_Flag'] == 1]

# Concatenando as duas amostras para criar um conjunto de dados balanceado
df_balanced = pd.concat([df_class_0, df_class_1])

# Embaralhando os dados para garantir que as classes estejam misturadas
df_balanced = df_balanced.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
df_balanced
# Out:
#        Age Married/Single  Experience          Profession  CURRENT_JOB_YRS  \
# 0       23         single           2                Chef                2
# 1       42         single           5            Surveyor                5
# 2       30         single           5          Technician                5
# 3       64         single           1      Police_officer                1
# 4       79         single           5          Politician                4
# ...    ...            ...         ...                 ...              ...
# 61987   59         single          14    Graphic_Designer                6
# 61988   67         single          16          Technician                3
# 61989   65         single          14           Architect               13
# 61990   24        married          10  Petroleum_Engineer                6
# 61991   56         single          13           Librarian               13
#
#       House_Ownership Car_Ownership  CURRENT_HOUSE_YRS  Risk_Flag     income
# 0              rented            no                 10          1  94968.408
# 1              rented            no                 11          1  22308.936
# 2              rented            no                 12          1   2737.572
# 3              rented            no                 14          0  65547.468
# 4              rented            no                 12          0   7823.100
# ...               ...           ...                ...        ...        ...
# 61987          rented           yes                 11          1    896.892
# 61988          rented           yes                 14          1  71428.452
# 61989          rented            no                 11          0  11862.480
# 61990          rented           yes                 12          0  28632.024
# 61991          rented            no                 11          1   3472.212
#
# [61992 rows x 10 columns]

# %%
def split_df(df_balanced):
    df_train, df_test = train_test_split(df_balanced, test_size=0.25, random_state=42)
    return df_train, df_test

df_train, df_test = split_df(df_balanced)

X_train = df_train.drop('Risk_Flag', axis=1)
y_train = df_train.Risk_Flag

X_test = df_test.drop('Risk_Flag', axis=1)
y_test = df_test.Risk_Flag

# %%
import pandas as pd
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, MaxAbsScaler, MinMaxScaler, Normalizer, RobustScaler
from sklearn.impute import SimpleImputer
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
import numpy as np
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import LabelEncoder

# Definindo random_state para reprodutibilidade
random_state = 10

class CustomLabelEncoder(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        self.label_encoders_ = {col: LabelEncoder().fit(X[col]) for col in X.columns}
        return self
    
    def transform(self, X):
        X = X.copy()
        for col, le in self.label_encoders_.items():
            X[col] = le.transform(X[col])
        return X

# Defina os transformadores para colunas numéricas e categóricas
numeric_features = X_train.select_dtypes(include=['int64', 'float64']).columns
categorical_features = X_train.select_dtypes(include=['object']).columns

# Pipeline para colunas numéricas
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median'))
])

# Pipeline para colunas categóricas
categorical_transformer = Pipeline(steps=[
    ('label_encoder', CustomLabelEncoder())
])

# Combine os transformadores usando ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)
    ])

# Define the scalers and models
scalers = {
    'None': None,
    'MaxAbsScaler': MaxAbsScaler(),
    'MinMaxScaler': MinMaxScaler(),
    'Normalizer': Normalizer(),
    'RobustScaler': RobustScaler(),
    'StandardScaler': StandardScaler()
}

models = {
    'Decision Tree': DecisionTreeClassifier(max_depth=5, random_state=random_state),
    'Logistic Regression': LogisticRegression(solver='liblinear', random_state=random_state),
    'Random Forest': RandomForestClassifier(n_estimators=100, random_state=random_state),
    'Gradient Boosting': GradientBoostingClassifier(n_estimators=100, max_depth=5, random_state=random_state),
    'LightGBM': LGBMClassifier(random_state=random_state),
    'XGBoost': XGBClassifier(n_estimators=100, max_depth=5, random_state=random_state)
}

# %%
# %%time
results = []
pipelines = {}

for scaler_name, scaler in scalers.items():
    for model_name, model in models.items():
        if scaler:
            pipeline = Pipeline(steps=[
                ('preprocessor', preprocessor),
                ('scaler', scaler),
                ('classifier', model)
            ])
        else:
            pipeline = Pipeline(steps=[
                ('preprocessor', preprocessor),
                ('classifier', model)
            ])
        
        cv_results = cross_validate(pipeline, X_train, y_train, cv=5, scoring=['accuracy', 'recall_macro', 'precision_macro', 'f1_macro'], return_train_score=False, )
        

        accuracy = cv_results['test_accuracy'].mean()
        recall = cv_results['test_recall_macro'].mean()
        precision = cv_results['test_precision_macro'].mean()
        f1 = cv_results['test_f1_macro'].mean()

        results.append({
            'Scaler': scaler_name,
            'Model': model_name,
            'Accuracy': accuracy,
            'Recall': recall,
            'Precision': precision,
            'F1 Score': f1
        })

        # Store pipeline with its configuration
        pipelines[(scaler_name, model_name)] = pipeline.fit(X_train, y_train)

        print(f"Scaler: {scaler_name}, Model: {model_name}")
        pipeline.fit(X_train, y_train)
        y_pred = pipeline.predict(X_test)
        
        print("\nClassification Report:")
        print(classification_report(y_test, y_pred))
        print("\n" + "-"*60 + "\n")

        # Optional: plot confusion matrix
        plt.figure(figsize=(10, 7))
        sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues')
        plt.title(f"Confusion Matrix: {scaler_name} - {model_name}")
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.show()

results_df = pd.DataFrame(results)
results_df
# Out:
# Scaler: None, Model: Decision Tree
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.55      0.63      0.59      7717
#            1       0.57      0.48      0.52      7781
#
#     accuracy                           0.56     15498
#    macro avg       0.56      0.56      0.55     15498
# weighted avg       0.56      0.56      0.55     15498
#
#
# ------------------------------------------------------------
# Scaler: None, Model: Logistic Regression
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.54      0.51      0.53      7717
#            1       0.54      0.56      0.55      7781
#
#     accuracy                           0.54     15498
#    macro avg       0.54      0.54      0.54     15498
# weighted avg       0.54      0.54      0.54     15498
#
#
# ------------------------------------------------------------
# Scaler: None, Model: Random Forest
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85      7717
#            1       0.88      0.81      0.84      7781
#
#     accuracy                           0.85     15498
#    macro avg       0.85      0.85      0.85     15498
# weighted avg       0.85      0.85      0.85     15498
#
#
# ------------------------------------------------------------
# Scaler: None, Model: Gradient Boosting
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.70      0.74      0.72      7717
#            1       0.72      0.68      0.70      7781
#
#     accuracy                           0.71     15498
#    macro avg       0.71      0.71      0.71     15498
# weighted avg       0.71      0.71      0.71     15498
#
#
# ------------------------------------------------------------
# [LightGBM] [Info] Number of positive: 18572, number of negative: 18623
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000574 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 415
# [LightGBM] [Info] Number of data points in the train set: 37195, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499314 -> initscore=-0.002742
# [LightGBM] [Info] Start training from score -0.002742
# [LightGBM] [Info] Number of positive: 18572, number of negative: 18623
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000529 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 415
# [LightGBM] [Info] Number of data points in the train set: 37195, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499314 -> initscore=-0.002742
# [LightGBM] [Info] Start training from score -0.002742
# [LightGBM] [Info] Number of positive: 18572, number of negative: 18623
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000549 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 415
# [LightGBM] [Info] Number of data points in the train set: 37195, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499314 -> initscore=-0.002742
# [LightGBM] [Info] Start training from score -0.002742
# [LightGBM] [Info] Number of positive: 18572, number of negative: 18623
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000547 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 415
# [LightGBM] [Info] Number of data points in the train set: 37195, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499314 -> initscore=-0.002742
# [LightGBM] [Info] Start training from score -0.002742
# [LightGBM] [Info] Number of positive: 18572, number of negative: 18624
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000581 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 415
# [LightGBM] [Info] Number of data points in the train set: 37196, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499301 -> initscore=-0.002796
# [LightGBM] [Info] Start training from score -0.002796
# [LightGBM] [Info] Number of positive: 23215, number of negative: 23279
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000721 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 415
# [LightGBM] [Info] Number of data points in the train set: 46494, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499312 -> initscore=-0.002753
# [LightGBM] [Info] Start training from score -0.002753
# Scaler: None, Model: LightGBM
# [LightGBM] [Info] Number of positive: 23215, number of negative: 23279
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000693 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 415
# [LightGBM] [Info] Number of data points in the train set: 46494, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499312 -> initscore=-0.002753
# [LightGBM] [Info] Start training from score -0.002753
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.78      0.76      7717
#            1       0.77      0.72      0.74      7781
#
#     accuracy                           0.75     15498
#    macro avg       0.75      0.75      0.75     15498
# weighted avg       0.75      0.75      0.75     15498
#
#
# ------------------------------------------------------------
# Scaler: None, Model: XGBoost
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.78      0.78      7717
#            1       0.78      0.78      0.78      7781
#
#     accuracy                           0.78     15498
#    macro avg       0.78      0.78      0.78     15498
# weighted avg       0.78      0.78      0.78     15498
#
#
# ------------------------------------------------------------
# Scaler: MaxAbsScaler, Model: Decision Tree
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.55      0.63      0.59      7717
#            1       0.57      0.48      0.52      7781
#
#     accuracy                           0.56     15498
#    macro avg       0.56      0.56      0.55     15498
# weighted avg       0.56      0.56      0.55     15498
#
#
# ------------------------------------------------------------
# Scaler: MaxAbsScaler, Model: Logistic Regression
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.54      0.51      0.53      7717
#            1       0.54      0.56      0.55      7781
#
#     accuracy                           0.54     15498
#    macro avg       0.54      0.54      0.54     15498
# weighted avg       0.54      0.54      0.54     15498
#
#
# ------------------------------------------------------------
# Scaler: MaxAbsScaler, Model: Random Forest
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85      7717
#            1       0.88      0.81      0.84      7781
#
#     accuracy                           0.85     15498
#    macro avg       0.85      0.85      0.85     15498
# weighted avg       0.85      0.85      0.85     15498
#
#
# ------------------------------------------------------------
# Scaler: MaxAbsScaler, Model: Gradient Boosting
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.70      0.74      0.72      7717
#            1       0.72      0.68      0.70      7781
#
#     accuracy                           0.71     15498
#    macro avg       0.71      0.71      0.71     15498
# weighted avg       0.71      0.71      0.71     15498
#
#
# ------------------------------------------------------------
# [LightGBM] [Info] Number of positive: 18572, number of negative: 18623
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000525 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 415
# [LightGBM] [Info] Number of data points in the train set: 37195, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499314 -> initscore=-0.002742
# [LightGBM] [Info] Start training from score -0.002742
# [LightGBM] [Info] Number of positive: 18572, number of negative: 18623
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000545 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 415
# [LightGBM] [Info] Number of data points in the train set: 37195, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499314 -> initscore=-0.002742
# [LightGBM] [Info] Start training from score -0.002742
# [LightGBM] [Info] Number of positive: 18572, number of negative: 18623
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000548 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 415
# [LightGBM] [Info] Number of data points in the train set: 37195, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499314 -> initscore=-0.002742
# [LightGBM] [Info] Start training from score -0.002742
# [LightGBM] [Info] Number of positive: 18572, number of negative: 18623
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000549 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 415
# [LightGBM] [Info] Number of data points in the train set: 37195, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499314 -> initscore=-0.002742
# [LightGBM] [Info] Start training from score -0.002742
# [LightGBM] [Info] Number of positive: 18572, number of negative: 18624
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000557 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 415
# [LightGBM] [Info] Number of data points in the train set: 37196, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499301 -> initscore=-0.002796
# [LightGBM] [Info] Start training from score -0.002796
# [LightGBM] [Info] Number of positive: 23215, number of negative: 23279
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000697 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 415
# [LightGBM] [Info] Number of data points in the train set: 46494, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499312 -> initscore=-0.002753
# [LightGBM] [Info] Start training from score -0.002753
# Scaler: MaxAbsScaler, Model: LightGBM
# [LightGBM] [Info] Number of positive: 23215, number of negative: 23279
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000691 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 415
# [LightGBM] [Info] Number of data points in the train set: 46494, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499312 -> initscore=-0.002753
# [LightGBM] [Info] Start training from score -0.002753
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.78      0.76      7717
#            1       0.77      0.72      0.74      7781
#
#     accuracy                           0.75     15498
#    macro avg       0.75      0.75      0.75     15498
# weighted avg       0.75      0.75      0.75     15498
#
#
# ------------------------------------------------------------
# Scaler: MaxAbsScaler, Model: XGBoost
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.78      0.78      7717
#            1       0.78      0.78      0.78      7781
#
#     accuracy                           0.78     15498
#    macro avg       0.78      0.78      0.78     15498
# weighted avg       0.78      0.78      0.78     15498
#
#
# ------------------------------------------------------------
# Scaler: MinMaxScaler, Model: Decision Tree
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.55      0.63      0.59      7717
#            1       0.57      0.48      0.52      7781
#
#     accuracy                           0.56     15498
#    macro avg       0.56      0.56      0.55     15498
# weighted avg       0.56      0.56      0.55     15498
#
#
# ------------------------------------------------------------
# Scaler: MinMaxScaler, Model: Logistic Regression
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.54      0.51      0.53      7717
#            1       0.54      0.56      0.55      7781
#
#     accuracy                           0.54     15498
#    macro avg       0.54      0.54      0.54     15498
# weighted avg       0.54      0.54      0.54     15498
#
#
# ------------------------------------------------------------
# Scaler: MinMaxScaler, Model: Random Forest
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85      7717
#            1       0.88      0.81      0.84      7781
#
#     accuracy                           0.85     15498
#    macro avg       0.85      0.85      0.85     15498
# weighted avg       0.85      0.85      0.85     15498
#
#
# ------------------------------------------------------------
# Scaler: MinMaxScaler, Model: Gradient Boosting
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.70      0.74      0.72      7717
#            1       0.72      0.68      0.70      7781
#
#     accuracy                           0.71     15498
#    macro avg       0.71      0.71      0.71     15498
# weighted avg       0.71      0.71      0.71     15498
#
#
# ------------------------------------------------------------
# [LightGBM] [Info] Number of positive: 18572, number of negative: 18623
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000556 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 413
# [LightGBM] [Info] Number of data points in the train set: 37195, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499314 -> initscore=-0.002742
# [LightGBM] [Info] Start training from score -0.002742
# [LightGBM] [Info] Number of positive: 18572, number of negative: 18623
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000554 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 413
# [LightGBM] [Info] Number of data points in the train set: 37195, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499314 -> initscore=-0.002742
# [LightGBM] [Info] Start training from score -0.002742
# [LightGBM] [Info] Number of positive: 18572, number of negative: 18623
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000564 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 413
# [LightGBM] [Info] Number of data points in the train set: 37195, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499314 -> initscore=-0.002742
# [LightGBM] [Info] Start training from score -0.002742
# [LightGBM] [Info] Number of positive: 18572, number of negative: 18623
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000552 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 413
# [LightGBM] [Info] Number of data points in the train set: 37195, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499314 -> initscore=-0.002742
# [LightGBM] [Info] Start training from score -0.002742
# [LightGBM] [Info] Number of positive: 18572, number of negative: 18624
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000527 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 413
# [LightGBM] [Info] Number of data points in the train set: 37196, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499301 -> initscore=-0.002796
# [LightGBM] [Info] Start training from score -0.002796
# [LightGBM] [Info] Number of positive: 23215, number of negative: 23279
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000700 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 413
# [LightGBM] [Info] Number of data points in the train set: 46494, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499312 -> initscore=-0.002753
# [LightGBM] [Info] Start training from score -0.002753
# Scaler: MinMaxScaler, Model: LightGBM
# [LightGBM] [Info] Number of positive: 23215, number of negative: 23279
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000706 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 413
# [LightGBM] [Info] Number of data points in the train set: 46494, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499312 -> initscore=-0.002753
# [LightGBM] [Info] Start training from score -0.002753
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.78      0.76      7717
#            1       0.77      0.72      0.74      7781
#
#     accuracy                           0.75     15498
#    macro avg       0.75      0.75      0.75     15498
# weighted avg       0.75      0.75      0.75     15498
#
#
# ------------------------------------------------------------
# Scaler: MinMaxScaler, Model: XGBoost
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.78      0.78      7717
#            1       0.78      0.78      0.78      7781
#
#     accuracy                           0.78     15498
#    macro avg       0.78      0.78      0.78     15498
# weighted avg       0.78      0.78      0.78     15498
#
#
# ------------------------------------------------------------
# Scaler: Normalizer, Model: Decision Tree
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.53      0.84      0.65      7717
#            1       0.61      0.25      0.35      7781
#
#     accuracy                           0.54     15498
#    macro avg       0.57      0.55      0.50     15498
# weighted avg       0.57      0.54      0.50     15498
#
#
# ------------------------------------------------------------
# Scaler: Normalizer, Model: Logistic Regression
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.50      0.94      0.66      7717
#            1       0.58      0.08      0.14      7781
#
#     accuracy                           0.51     15498
#    macro avg       0.54      0.51      0.40     15498
# weighted avg       0.54      0.51      0.40     15498
#
#
# ------------------------------------------------------------
# Scaler: Normalizer, Model: Random Forest
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.85      7717
#            1       0.88      0.82      0.85      7781
#
#     accuracy                           0.85     15498
#    macro avg       0.85      0.85      0.85     15498
# weighted avg       0.85      0.85      0.85     15498
#
#
# ------------------------------------------------------------
# Scaler: Normalizer, Model: Gradient Boosting
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.72      0.75      0.73      7717
#            1       0.74      0.71      0.72      7781
#
#     accuracy                           0.73     15498
#    macro avg       0.73      0.73      0.73     15498
# weighted avg       0.73      0.73      0.73     15498
#
#
# ------------------------------------------------------------
# [LightGBM] [Info] Number of positive: 18572, number of negative: 18623
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000134 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2294
# [LightGBM] [Info] Number of data points in the train set: 37195, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499314 -> initscore=-0.002742
# [LightGBM] [Info] Start training from score -0.002742
# [LightGBM] [Info] Number of positive: 18572, number of negative: 18623
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000138 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2294
# [LightGBM] [Info] Number of data points in the train set: 37195, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499314 -> initscore=-0.002742
# [LightGBM] [Info] Start training from score -0.002742
# [LightGBM] [Info] Number of positive: 18572, number of negative: 18623
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000140 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 37195, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499314 -> initscore=-0.002742
# [LightGBM] [Info] Start training from score -0.002742
# [LightGBM] [Info] Number of positive: 18572, number of negative: 18623
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000143 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2294
# [LightGBM] [Info] Number of data points in the train set: 37195, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499314 -> initscore=-0.002742
# [LightGBM] [Info] Start training from score -0.002742
# [LightGBM] [Info] Number of positive: 18572, number of negative: 18624
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000142 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2294
# [LightGBM] [Info] Number of data points in the train set: 37196, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499301 -> initscore=-0.002796
# [LightGBM] [Info] Start training from score -0.002796
# [LightGBM] [Info] Number of positive: 23215, number of negative: 23279
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000166 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2294
# [LightGBM] [Info] Number of data points in the train set: 46494, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499312 -> initscore=-0.002753
# [LightGBM] [Info] Start training from score -0.002753
# Scaler: Normalizer, Model: LightGBM
# [LightGBM] [Info] Number of positive: 23215, number of negative: 23279
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000166 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2294
# [LightGBM] [Info] Number of data points in the train set: 46494, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499312 -> initscore=-0.002753
# [LightGBM] [Info] Start training from score -0.002753
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.78      0.78      7717
#            1       0.78      0.78      0.78      7781
#
#     accuracy                           0.78     15498
#    macro avg       0.78      0.78      0.78     15498
# weighted avg       0.78      0.78      0.78     15498
#
#
# ------------------------------------------------------------
# Scaler: Normalizer, Model: XGBoost
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.80      0.80      7717
#            1       0.80      0.80      0.80      7781
#
#     accuracy                           0.80     15498
#    macro avg       0.80      0.80      0.80     15498
# weighted avg       0.80      0.80      0.80     15498
#
#
# ------------------------------------------------------------
# Scaler: RobustScaler, Model: Decision Tree
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.55      0.63      0.59      7717
#            1       0.57      0.48      0.52      7781
#
#     accuracy                           0.56     15498
#    macro avg       0.56      0.56      0.55     15498
# weighted avg       0.56      0.56      0.55     15498
#
#
# ------------------------------------------------------------
# Scaler: RobustScaler, Model: Logistic Regression
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.54      0.51      0.53      7717
#            1       0.54      0.56      0.55      7781
#
#     accuracy                           0.54     15498
#    macro avg       0.54      0.54      0.54     15498
# weighted avg       0.54      0.54      0.54     15498
#
#
# ------------------------------------------------------------
# Scaler: RobustScaler, Model: Random Forest
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85      7717
#            1       0.88      0.81      0.84      7781
#
#     accuracy                           0.85     15498
#    macro avg       0.85      0.85      0.85     15498
# weighted avg       0.85      0.85      0.85     15498
#
#
# ------------------------------------------------------------
# Scaler: RobustScaler, Model: Gradient Boosting
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.70      0.74      0.72      7717
#            1       0.72      0.68      0.70      7781
#
#     accuracy                           0.71     15498
#    macro avg       0.71      0.71      0.71     15498
# weighted avg       0.71      0.71      0.71     15498
#
#
# ------------------------------------------------------------
# [LightGBM] [Info] Number of positive: 18572, number of negative: 18623
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000561 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 413
# [LightGBM] [Info] Number of data points in the train set: 37195, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499314 -> initscore=-0.002742
# [LightGBM] [Info] Start training from score -0.002742
# [LightGBM] [Info] Number of positive: 18572, number of negative: 18623
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000585 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 413
# [LightGBM] [Info] Number of data points in the train set: 37195, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499314 -> initscore=-0.002742
# [LightGBM] [Info] Start training from score -0.002742
# [LightGBM] [Info] Number of positive: 18572, number of negative: 18623
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000584 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 413
# [LightGBM] [Info] Number of data points in the train set: 37195, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499314 -> initscore=-0.002742
# [LightGBM] [Info] Start training from score -0.002742
# [LightGBM] [Info] Number of positive: 18572, number of negative: 18623
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000587 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 413
# [LightGBM] [Info] Number of data points in the train set: 37195, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499314 -> initscore=-0.002742
# [LightGBM] [Info] Start training from score -0.002742
# [LightGBM] [Info] Number of positive: 18572, number of negative: 18624
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000581 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 413
# [LightGBM] [Info] Number of data points in the train set: 37196, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499301 -> initscore=-0.002796
# [LightGBM] [Info] Start training from score -0.002796
# [LightGBM] [Info] Number of positive: 23215, number of negative: 23279
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000729 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 413
# [LightGBM] [Info] Number of data points in the train set: 46494, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499312 -> initscore=-0.002753
# [LightGBM] [Info] Start training from score -0.002753
# Scaler: RobustScaler, Model: LightGBM
# [LightGBM] [Info] Number of positive: 23215, number of negative: 23279
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000697 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 413
# [LightGBM] [Info] Number of data points in the train set: 46494, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499312 -> initscore=-0.002753
# [LightGBM] [Info] Start training from score -0.002753
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.79      0.77      7717
#            1       0.78      0.72      0.75      7781
#
#     accuracy                           0.76     15498
#    macro avg       0.76      0.76      0.76     15498
# weighted avg       0.76      0.76      0.76     15498
#
#
# ------------------------------------------------------------
# Scaler: RobustScaler, Model: XGBoost
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.78      0.78      7717
#            1       0.78      0.78      0.78      7781
#
#     accuracy                           0.78     15498
#    macro avg       0.78      0.78      0.78     15498
# weighted avg       0.78      0.78      0.78     15498
#
#
# ------------------------------------------------------------
# Scaler: StandardScaler, Model: Decision Tree
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.55      0.63      0.59      7717
#            1       0.57      0.48      0.52      7781
#
#     accuracy                           0.56     15498
#    macro avg       0.56      0.56      0.55     15498
# weighted avg       0.56      0.56      0.55     15498
#
#
# ------------------------------------------------------------
# Scaler: StandardScaler, Model: Logistic Regression
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.54      0.51      0.53      7717
#            1       0.54      0.56      0.55      7781
#
#     accuracy                           0.54     15498
#    macro avg       0.54      0.54      0.54     15498
# weighted avg       0.54      0.54      0.54     15498
#
#
# ------------------------------------------------------------
# Scaler: StandardScaler, Model: Random Forest
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85      7717
#            1       0.88      0.81      0.84      7781
#
#     accuracy                           0.85     15498
#    macro avg       0.85      0.85      0.85     15498
# weighted avg       0.85      0.85      0.85     15498
#
#
# ------------------------------------------------------------
# Scaler: StandardScaler, Model: Gradient Boosting
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.70      0.74      0.72      7717
#            1       0.72      0.68      0.70      7781
#
#     accuracy                           0.71     15498
#    macro avg       0.71      0.71      0.71     15498
# weighted avg       0.71      0.71      0.71     15498
#
#
# ------------------------------------------------------------
# [LightGBM] [Info] Number of positive: 18572, number of negative: 18623
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000585 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 421
# [LightGBM] [Info] Number of data points in the train set: 37195, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499314 -> initscore=-0.002742
# [LightGBM] [Info] Start training from score -0.002742
# [LightGBM] [Info] Number of positive: 18572, number of negative: 18623
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000578 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 421
# [LightGBM] [Info] Number of data points in the train set: 37195, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499314 -> initscore=-0.002742
# [LightGBM] [Info] Start training from score -0.002742
# [LightGBM] [Info] Number of positive: 18572, number of negative: 18623
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000554 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 421
# [LightGBM] [Info] Number of data points in the train set: 37195, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499314 -> initscore=-0.002742
# [LightGBM] [Info] Start training from score -0.002742
# [LightGBM] [Info] Number of positive: 18572, number of negative: 18623
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000555 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 421
# [LightGBM] [Info] Number of data points in the train set: 37195, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499314 -> initscore=-0.002742
# [LightGBM] [Info] Start training from score -0.002742
# [LightGBM] [Info] Number of positive: 18572, number of negative: 18624
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000547 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 421
# [LightGBM] [Info] Number of data points in the train set: 37196, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499301 -> initscore=-0.002796
# [LightGBM] [Info] Start training from score -0.002796
# [LightGBM] [Info] Number of positive: 23215, number of negative: 23279
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000687 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 421
# [LightGBM] [Info] Number of data points in the train set: 46494, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499312 -> initscore=-0.002753
# [LightGBM] [Info] Start training from score -0.002753
# Scaler: StandardScaler, Model: LightGBM
# [LightGBM] [Info] Number of positive: 23215, number of negative: 23279
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000667 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 421
# [LightGBM] [Info] Number of data points in the train set: 46494, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499312 -> initscore=-0.002753
# [LightGBM] [Info] Start training from score -0.002753
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.79      0.76      7717
#            1       0.78      0.73      0.75      7781
#
#     accuracy                           0.76     15498
#    macro avg       0.76      0.76      0.76     15498
# weighted avg       0.76      0.76      0.76     15498
#
#
# ------------------------------------------------------------
# Scaler: StandardScaler, Model: XGBoost
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.78      0.78      7717
#            1       0.78      0.78      0.78      7781
#
#     accuracy                           0.78     15498
#    macro avg       0.78      0.78      0.78     15498
# weighted avg       0.78      0.78      0.78     15498
#
#
# ------------------------------------------------------------
# CPU times: user 6min 59s, sys: 43.9 s, total: 7min 43s
# Wall time: 5min 54s
#             Scaler                Model  Accuracy    Recall  Precision  \
# 0             None        Decision Tree  0.550351  0.550161   0.555638
# 1             None  Logistic Regression  0.534348  0.534385   0.534483
# 2             None        Random Forest  0.847228  0.847176   0.849188
# 3             None    Gradient Boosting  0.702542  0.702516   0.702862
# 4             None             LightGBM  0.753323  0.753301   0.753700
# 5             None              XGBoost  0.774014  0.774022   0.774076
# 6     MaxAbsScaler        Decision Tree  0.550351  0.550161   0.555638
# 7     MaxAbsScaler  Logistic Regression  0.534284  0.534322   0.534428
# 8     MaxAbsScaler        Random Forest  0.847550  0.847499   0.849523
# 9     MaxAbsScaler    Gradient Boosting  0.702499  0.702473   0.702816
# 10    MaxAbsScaler             LightGBM  0.753323  0.753301   0.753700
# 11    MaxAbsScaler              XGBoost  0.774014  0.774022   0.774076
# 12    MinMaxScaler        Decision Tree  0.550351  0.550161   0.555638
# 13    MinMaxScaler  Logistic Regression  0.534370  0.534408   0.534514
# 14    MinMaxScaler        Random Forest  0.847443  0.847392   0.849387
# 15    MinMaxScaler    Gradient Boosting  0.702456  0.702430   0.702774
# 16    MinMaxScaler             LightGBM  0.752850  0.752831   0.753129
# 17    MinMaxScaler              XGBoost  0.774014  0.774022   0.774076
# 18      Normalizer        Decision Tree  0.542629  0.542284   0.558703
# 19      Normalizer  Logistic Regression  0.507506  0.506911   0.529204
# 20      Normalizer        Random Forest  0.848540  0.848493   0.850150
# 21      Normalizer    Gradient Boosting  0.731191  0.731148   0.732106
# 22      Normalizer             LightGBM  0.776595  0.776592   0.776623
# 23      Normalizer              XGBoost  0.789392  0.789397   0.789429
# 24    RobustScaler        Decision Tree  0.550351  0.550161   0.555638
# 25    RobustScaler  Logistic Regression  0.534047  0.534085   0.534190
# 26    RobustScaler        Random Forest  0.847228  0.847176   0.849210
# 27    RobustScaler    Gradient Boosting  0.702499  0.702473   0.702817
# 28    RobustScaler             LightGBM  0.750699  0.750681   0.750895
# 29    RobustScaler              XGBoost  0.774014  0.774022   0.774076
# 30  StandardScaler        Decision Tree  0.550351  0.550161   0.555638
# 31  StandardScaler  Logistic Regression  0.533961  0.533999   0.534104
# 32  StandardScaler        Random Forest  0.847400  0.847348   0.849398
# 33  StandardScaler    Gradient Boosting  0.702456  0.702430   0.702773
# 34  StandardScaler             LightGBM  0.751151  0.751128   0.751517
# 35  StandardScaler              XGBoost  0.774014  0.774022   0.774076
#
#     F1 Score
# 0   0.539159
# 1   0.534028
# 2   0.846998
# 3   0.702402
# 4   0.753217
# 5   0.774005
# 6   0.539159
# 7   0.533937
# 8   0.847320
# 9   0.702360
# 10  0.753217
# 11  0.774005
# 12  0.539159
# 13  0.534024
# 14  0.847216
# 15  0.702317
# 16  0.752773
# 17  0.774005
# 18  0.509549
# 19  0.393858
# 20  0.848353
# 21  0.730901
# 22  0.776588
# 23  0.789387
# 24  0.539159
# 25  0.533701
# 26  0.846996
# 27  0.702360
# 28  0.750641
# 29  0.774005
# 30  0.539159
# 31  0.533613
# 32  0.847166
# 33  0.702317
# 34  0.751041
# 35  0.774005

# %%
results_df[results_df['Model']=='Random Forest']
# Out:
#             Scaler          Model  Accuracy    Recall  Precision  F1 Score
# 2             None  Random Forest  0.847228  0.847176   0.849188  0.846998
# 8     MaxAbsScaler  Random Forest  0.847550  0.847499   0.849523  0.847320
# 14    MinMaxScaler  Random Forest  0.847443  0.847392   0.849387  0.847216
# 20      Normalizer  Random Forest  0.848540  0.848493   0.850150  0.848353
# 26    RobustScaler  Random Forest  0.847228  0.847176   0.849210  0.846996
# 32  StandardScaler  Random Forest  0.847400  0.847348   0.849398  0.847166

# %%
# Identifique o melhor modelo com base na acurácia
best_model_info = results_df.loc[results_df['Accuracy'].idxmax()]
best_scaler = best_model_info['Scaler']
best_model_name = best_model_info['Model']
best_pipeline = pipelines[(best_scaler, best_model_name)]

print(f"Best Model: {best_model_name} with Scaler: {best_scaler}")

# Extraindo o modelo Random Forest do pipeline
if best_model_name == 'Random Forest':
    random_forest_model = best_pipeline.named_steps['classifier']
    print("Random Forest Model Extracted")
else:
    print(f"The best model is not Random Forest, it is {best_model_name} with Scaler: {best_scaler}")
# Out:
# Best Model: Random Forest with Scaler: Normalizer
# Random Forest Model Extracted

# %%
# Extraindo o modelo Random Forest do pipeline
if best_model_name == 'Random Forest':
    random_forest_model = best_pipeline.named_steps['classifier']
    preprocessor = best_pipeline.named_steps['preprocessor']

    # Avaliando a importância das features
    import matplotlib.pyplot as plt

    # Recuperar nomes das features após a transformação
    all_feature_names = numeric_features.tolist() + categorical_features.tolist()

    # Importâncias das features
    feature_importances = random_forest_model.feature_importances_

    # Criando um DataFrame para as importâncias das features
    feature_importances_df = pd.DataFrame({
        'Feature': all_feature_names,
        'Importance': feature_importances
    }).sort_values(by='Importance', ascending=False)

    # Filtrar features com importância acima de 0.025
    filtered_feature_importances_df = feature_importances_df[feature_importances_df['Importance'] > 0.001]

    # Plotar as importâncias das features filtradas
    plt.figure(figsize=(12, 8))
    plt.barh(filtered_feature_importances_df['Feature'], filtered_feature_importances_df['Importance'])
    plt.xlabel('Importance')
    plt.ylabel('Feature')
    plt.title('Feature Importances (Importance > 0.025)')
    plt.gca().invert_yaxis()
    plt.show()
else:
    print(f"The best model is not Random Forest, it is {best_model_name} with Scaler: {best_scaler}")

# %%
feature_importances_df
# Out:
#              Feature  Importance
# 4             income    0.267022
# 6         Profession    0.200252
# 0                Age    0.199603
# 1         Experience    0.105091
# 2    CURRENT_JOB_YRS    0.095646
# 3  CURRENT_HOUSE_YRS    0.082044
# 8      Car_Ownership    0.022515
# 5     Married/Single    0.014074
# 7    House_Ownership    0.013751

# %%
# %%time

import shap

# Transformar o conjunto de teste usando o pré-processador
X_test_transformed = preprocessor.transform(X_test)
# Out:
# CPU times: user 231 ms, sys: 9.08 ms, total: 240 ms
# Wall time: 240 ms

# %%
# Transformar o array X_test_transformed de volta em um DataFrame
#df_test_transformed = pd.DataFrame(X_test_transformed, columns=numeric_features.tolist() + categorical_features.tolist())
#df_test_transformed

# %%
# %%time
# Criar o objeto explainer para o modelo Random Forest
explainer = shap.TreeExplainer(best_pipeline.named_steps['classifier'])

# Calcular os SHAP values para o conjunto de teste transformado
shap_values = explainer.shap_values(X_test_transformed)

# Plotar o gráfico de SHAP values
shap.summary_plot(shap_values, X_test_transformed, feature_names=all_feature_names)

# %%
shap.initjs()

shap.force_plot(explainer.expected_value[1], shap_values[1][:2000,:], X_train.iloc[:2000,:])

# %%
shap.waterfall_plot(
    shap.Explanation(
        values=shap_values[1][35], 
        base_values=explainer.expected_value[1], 
        data=X_test_transformed[0],
        feature_names=all_feature_names
    )
)

# %%
# Plotar o gráfico de SHAP values
shap.summary_plot(shap_values, X_test_transformed, feature_names=all_feature_names, plot_type="bar")

# %%
# Obter o modelo Random Forest do pipeline
model = best_pipeline.named_steps['classifier']

# Fazer previsões com o modelo
preds = model.predict(X_test_transformed)

# Inicializar uma lista para armazenar os novos valores SHAP
new_shap_values = []

# Ajustar os valores SHAP para a classe prevista
if isinstance(shap_values, list):
    # Para cada previsão, pegue os valores SHAP correspondentes à classe prevista
    for i, pred in enumerate(preds):
        new_shap_values.append(shap_values[pred][i])

    # Converter a lista de novos valores SHAP para um array NumPy
    new_shap_values = np.array(new_shap_values)

    # Verificar a nova estrutura de SHAP values
    print(new_shap_values.shape)
else:
    raise ValueError("shap_values should be a list of arrays for classification problems.")

# Criar um objeto shap.Explanation
shap_explanation = shap.Explanation(
    values=new_shap_values,
    base_values=explainer.expected_value[1],  # Base values para a segunda classe
    data=X_test_transformed,
    feature_names=all_feature_names
)

# Plotar o gráfico beeswarm usando o objeto Explanation
shap.plots.beeswarm(shap_explanation)

# %% [markdown]
# ### HIPERPARAMETROS

# %%
import optuna

# %%
#Definir o pré-processador (substitua com seu pré-processador real)
preprocessor = best_pipeline.named_steps['preprocessor']

# Função objetivo para o Optuna
def objective(trial):
    # Sugerir valores para os hiperparâmetros
    n_estimators = trial.suggest_int('n_estimators', 10, 300)
    max_depth = trial.suggest_int('max_depth', 2, 32)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 20)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 20)

    # Definir o modelo com os hiperparâmetros sugeridos
    model = RandomForestClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        random_state=42
    )

    # Criar o pipeline com o pré-processador e o modelo
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('classifier', model)
    ])

    # Avaliar o modelo com validação cruzada
    scores = cross_val_score(pipeline, X_train, y_train, cv=5, scoring='accuracy')
    accuracy = scores.mean()
    
    return accuracy

# %%
# Lista para armazenar as métricas dos modelos
model_results2 = []

# Criar o estudo Optuna e otimizar
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)

# Exibir os melhores hiperparâmetros
print("Best hyperparameters: ", study.best_params)

# Treinar o modelo final com os melhores hiperparâmetros
best_params = study.best_params
final_model = RandomForestClassifier(
    n_estimators=best_params['n_estimators'],
    max_depth=best_params['max_depth'],
    min_samples_split=best_params['min_samples_split'],
    min_samples_leaf=best_params['min_samples_leaf'],
    random_state=42
)

# Criar o pipeline final com o pré-processador e o modelo
final_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('classifier', final_model)
])

# Treinar o pipeline final no conjunto de treino
final_pipeline.fit(X_train, y_train)

# Avaliar o desempenho no conjunto de teste
y_pred = final_pipeline.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
recall = recall_score(y_test, y_pred, average='macro')
precision = precision_score(y_test, y_pred, average='macro')
f1 = f1_score(y_test, y_pred, average='macro')

print("Test set accuracy: ", accuracy)
print(f"Classification Report:\n")
print(classification_report(y_test, y_pred))
print(f"Confusion Matrix:\n")
print(confusion_matrix(y_test, y_pred))
print("\n")

# Adicionar as métricas ao resultado
model_results2.append({
    'Model': 'tunagem_hyperparametro',
    'Accuracy': accuracy,
    'Recall': recall,
    'Precision': precision,
    'F1 Score': f1
})

# Criar um DataFrame com os resultados
results_df2 = pd.DataFrame(model_results2)
# Out:
# [I 2024-05-23 17:27:44,574] A new study created in memory with name: no-name-90882d8a-f52e-4cb3-a72d-cd4933600cb9
# [I 2024-05-23 17:27:55,673] Trial 0 finished with value: 0.811394994768922 and parameters: {'n_estimators': 105, 'max_depth': 14, 'min_samples_split': 5, 'min_samples_leaf': 13}. Best is trial 0 with value: 0.811394994768922.
# [I 2024-05-23 17:28:22,600] Trial 1 finished with value: 0.8393986697200585 and parameters: {'n_estimators': 220, 'max_depth': 32, 'min_samples_split': 9, 'min_samples_leaf': 10}. Best is trial 1 with value: 0.8393986697200585.
# [I 2024-05-23 17:28:45,104] Trial 2 finished with value: 0.8151160262099573 and parameters: {'n_estimators': 212, 'max_depth': 15, 'min_samples_split': 14, 'min_samples_leaf': 17}. Best is trial 1 with value: 0.8393986697200585.
# [I 2024-05-23 17:29:17,792] Trial 3 finished with value: 0.824256962894564 and parameters: {'n_estimators': 296, 'max_depth': 18, 'min_samples_split': 11, 'min_samples_leaf': 18}. Best is trial 1 with value: 0.8393986697200585.
# [I 2024-05-23 17:29:25,998] Trial 4 finished with value: 0.8161913551442458 and parameters: {'n_estimators': 77, 'max_depth': 13, 'min_samples_split': 7, 'min_samples_leaf': 2}. Best is trial 1 with value: 0.8393986697200585.
# [I 2024-05-23 17:29:28,376] Trial 5 finished with value: 0.8264938180660932 and parameters: {'n_estimators': 18, 'max_depth': 25, 'min_samples_split': 16, 'min_samples_leaf': 14}. Best is trial 1 with value: 0.8393986697200585.
# [I 2024-05-23 17:29:34,018] Trial 6 finished with value: 0.6537619568860353 and parameters: {'n_estimators': 73, 'max_depth': 8, 'min_samples_split': 15, 'min_samples_leaf': 16}. Best is trial 1 with value: 0.8393986697200585.
# [I 2024-05-23 17:29:37,749] Trial 7 finished with value: 0.5691486565987025 and parameters: {'n_estimators': 66, 'max_depth': 5, 'min_samples_split': 7, 'min_samples_leaf': 3}. Best is trial 1 with value: 0.8393986697200585.
# [I 2024-05-23 17:29:59,576] Trial 8 finished with value: 0.6633330126533357 and parameters: {'n_estimators': 298, 'max_depth': 8, 'min_samples_split': 16, 'min_samples_leaf': 12}. Best is trial 1 with value: 0.8393986697200585.
# [I 2024-05-23 17:30:11,969] Trial 9 finished with value: 0.8094163197651614 and parameters: {'n_estimators': 118, 'max_depth': 15, 'min_samples_split': 15, 'min_samples_leaf': 20}. Best is trial 1 with value: 0.8393986697200585.
# [I 2024-05-23 17:30:37,367] Trial 10 finished with value: 0.8424528124472385 and parameters: {'n_estimators': 202, 'max_depth': 32, 'min_samples_split': 2, 'min_samples_leaf': 7}. Best is trial 10 with value: 0.8424528124472385.
# [I 2024-05-23 17:31:01,785] Trial 11 finished with value: 0.8426463885876844 and parameters: {'n_estimators': 194, 'max_depth': 32, 'min_samples_split': 2, 'min_samples_leaf': 7}. Best is trial 11 with value: 0.8426463885876844.
# [I 2024-05-23 17:31:25,496] Trial 12 finished with value: 0.8427539154669175 and parameters: {'n_estimators': 188, 'max_depth': 30, 'min_samples_split': 2, 'min_samples_leaf': 7}. Best is trial 12 with value: 0.8427539154669175.
# [I 2024-05-23 17:31:45,804] Trial 13 finished with value: 0.8427969377843718 and parameters: {'n_estimators': 161, 'max_depth': 27, 'min_samples_split': 2, 'min_samples_leaf': 7}. Best is trial 13 with value: 0.8427969377843718.
# [I 2024-05-23 17:32:03,652] Trial 14 finished with value: 0.8422161792920557 and parameters: {'n_estimators': 144, 'max_depth': 24, 'min_samples_split': 20, 'min_samples_leaf': 6}. Best is trial 13 with value: 0.8427969377843718.
# [I 2024-05-23 17:32:23,645] Trial 15 finished with value: 0.8408827025741289 and parameters: {'n_estimators': 162, 'max_depth': 26, 'min_samples_split': 4, 'min_samples_leaf': 9}. Best is trial 13 with value: 0.8427969377843718.
# [I 2024-05-23 17:32:55,106] Trial 16 finished with value: 0.8435281992103315 and parameters: {'n_estimators': 250, 'max_depth': 21, 'min_samples_split': 4, 'min_samples_leaf': 4}. Best is trial 16 with value: 0.8435281992103315.
# [I 2024-05-23 17:33:27,025] Trial 17 finished with value: 0.8449477390683839 and parameters: {'n_estimators': 254, 'max_depth': 20, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 17 with value: 0.8449477390683839.
# [I 2024-05-23 17:33:58,983] Trial 18 finished with value: 0.8445175852884077 and parameters: {'n_estimators': 258, 'max_depth': 20, 'min_samples_split': 5, 'min_samples_leaf': 4}. Best is trial 17 with value: 0.8449477390683839.
# [I 2024-05-23 17:34:31,510] Trial 19 finished with value: 0.8445390536538193 and parameters: {'n_estimators': 258, 'max_depth': 20, 'min_samples_split': 11, 'min_samples_leaf': 1}. Best is trial 17 with value: 0.8449477390683839.
# [I 2024-05-23 17:34:54,589] Trial 20 finished with value: 0.7723792326954995 and parameters: {'n_estimators': 250, 'max_depth': 11, 'min_samples_split': 12, 'min_samples_leaf': 1}. Best is trial 17 with value: 0.8449477390683839.
# [I 2024-05-23 17:35:26,894] Trial 21 finished with value: 0.8443240137742661 and parameters: {'n_estimators': 260, 'max_depth': 20, 'min_samples_split': 8, 'min_samples_leaf': 4}. Best is trial 17 with value: 0.8449477390683839.
# [I 2024-05-23 17:36:01,356] Trial 22 finished with value: 0.8454638981596816 and parameters: {'n_estimators': 267, 'max_depth': 21, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 22 with value: 0.8454638981596816.
# [I 2024-05-23 17:36:37,896] Trial 23 finished with value: 0.8447756775563935 and parameters: {'n_estimators': 278, 'max_depth': 23, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 22 with value: 0.8454638981596816.
# [I 2024-05-23 17:37:14,553] Trial 24 finished with value: 0.8445820852238823 and parameters: {'n_estimators': 281, 'max_depth': 22, 'min_samples_split': 9, 'min_samples_leaf': 1}. Best is trial 22 with value: 0.8454638981596816.
# [I 2024-05-23 17:37:43,923] Trial 25 finished with value: 0.843872354618443 and parameters: {'n_estimators': 229, 'max_depth': 28, 'min_samples_split': 6, 'min_samples_leaf': 5}. Best is trial 22 with value: 0.8454638981596816.
# [I 2024-05-23 17:38:19,767] Trial 26 finished with value: 0.8447326806836133 and parameters: {'n_estimators': 279, 'max_depth': 23, 'min_samples_split': 9, 'min_samples_leaf': 3}. Best is trial 22 with value: 0.8454638981596816.
# [I 2024-05-23 17:38:47,716] Trial 27 finished with value: 0.8424527731236513 and parameters: {'n_estimators': 234, 'max_depth': 17, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 22 with value: 0.8454638981596816.
# [I 2024-05-23 17:39:20,821] Trial 28 finished with value: 0.8432055954411102 and parameters: {'n_estimators': 276, 'max_depth': 18, 'min_samples_split': 11, 'min_samples_leaf': 3}. Best is trial 22 with value: 0.8454638981596816.
# [I 2024-05-23 17:39:43,831] Trial 29 finished with value: 0.8443025037721151 and parameters: {'n_estimators': 180, 'max_depth': 29, 'min_samples_split': 6, 'min_samples_leaf': 5}. Best is trial 22 with value: 0.8454638981596816.
# [I 2024-05-23 17:40:12,723] Trial 30 finished with value: 0.8407751687554393 and parameters: {'n_estimators': 237, 'max_depth': 24, 'min_samples_split': 8, 'min_samples_leaf': 9}. Best is trial 22 with value: 0.8454638981596816.
# [I 2024-05-23 17:40:48,811] Trial 31 finished with value: 0.8447326506126348 and parameters: {'n_estimators': 279, 'max_depth': 23, 'min_samples_split': 9, 'min_samples_leaf': 2}. Best is trial 22 with value: 0.8454638981596816.
# [I 2024-05-23 17:41:23,991] Trial 32 finished with value: 0.8418935593307688 and parameters: {'n_estimators': 300, 'max_depth': 17, 'min_samples_split': 10, 'min_samples_leaf': 3}. Best is trial 22 with value: 0.8454638981596816.
# [I 2024-05-23 17:41:58,789] Trial 33 finished with value: 0.8432700930634326 and parameters: {'n_estimators': 272, 'max_depth': 22, 'min_samples_split': 13, 'min_samples_leaf': 1}. Best is trial 22 with value: 0.8454638981596816.
# [I 2024-05-23 17:42:26,199] Trial 34 finished with value: 0.8443670407180246 and parameters: {'n_estimators': 215, 'max_depth': 25, 'min_samples_split': 6, 'min_samples_leaf': 5}. Best is trial 22 with value: 0.8454638981596816.
# [I 2024-05-23 17:43:00,936] Trial 35 finished with value: 0.8442594421310737 and parameters: {'n_estimators': 282, 'max_depth': 19, 'min_samples_split': 8, 'min_samples_leaf': 3}. Best is trial 22 with value: 0.8454638981596816.
# [I 2024-05-23 17:43:26,966] Trial 36 finished with value: 0.8300641106319622 and parameters: {'n_estimators': 242, 'max_depth': 14, 'min_samples_split': 9, 'min_samples_leaf': 2}. Best is trial 22 with value: 0.8454638981596816.
# [I 2024-05-23 17:43:56,143] Trial 37 finished with value: 0.8293328353270895 and parameters: {'n_estimators': 266, 'max_depth': 16, 'min_samples_split': 10, 'min_samples_leaf': 12}. Best is trial 22 with value: 0.8454638981596816.
# [I 2024-05-23 17:44:22,190] Trial 38 finished with value: 0.8401299357723225 and parameters: {'n_estimators': 215, 'max_depth': 22, 'min_samples_split': 7, 'min_samples_leaf': 9}. Best is trial 22 with value: 0.8454638981596816.
# [I 2024-05-23 17:44:24,441] Trial 39 finished with value: 0.8471845202190436 and parameters: {'n_estimators': 15, 'max_depth': 26, 'min_samples_split': 5, 'min_samples_leaf': 2}. Best is trial 39 with value: 0.8471845202190436.
# [I 2024-05-23 17:44:27,692] Trial 40 finished with value: 0.8492923639538628 and parameters: {'n_estimators': 22, 'max_depth': 27, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 40 with value: 0.8492923639538628.
# [I 2024-05-23 17:44:33,016] Trial 41 finished with value: 0.8485610840226855 and parameters: {'n_estimators': 37, 'max_depth': 26, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 40 with value: 0.8492923639538628.
# [I 2024-05-23 17:44:35,142] Trial 42 finished with value: 0.8465823211191419 and parameters: {'n_estimators': 14, 'max_depth': 27, 'min_samples_split': 5, 'min_samples_leaf': 2}. Best is trial 40 with value: 0.8492923639538628.
# [I 2024-05-23 17:44:36,821] Trial 43 finished with value: 0.8216974623170739 and parameters: {'n_estimators': 12, 'max_depth': 30, 'min_samples_split': 3, 'min_samples_leaf': 15}. Best is trial 40 with value: 0.8492923639538628.
# [I 2024-05-23 17:44:41,467] Trial 44 finished with value: 0.8475931871283906 and parameters: {'n_estimators': 33, 'max_depth': 27, 'min_samples_split': 3, 'min_samples_leaf': 2}. Best is trial 40 with value: 0.8492923639538628.
# [I 2024-05-23 17:44:46,389] Trial 45 finished with value: 0.8477652532666855 and parameters: {'n_estimators': 35, 'max_depth': 27, 'min_samples_split': 3, 'min_samples_leaf': 2}. Best is trial 40 with value: 0.8492923639538628.
# [I 2024-05-23 17:44:51,457] Trial 46 finished with value: 0.843571237719851 and parameters: {'n_estimators': 37, 'max_depth': 30, 'min_samples_split': 3, 'min_samples_leaf': 4}. Best is trial 40 with value: 0.8492923639538628.
# [I 2024-05-23 17:44:53,085] Trial 47 finished with value: 0.5371230229864178 and parameters: {'n_estimators': 45, 'max_depth': 2, 'min_samples_split': 3, 'min_samples_leaf': 6}. Best is trial 40 with value: 0.8492923639538628.
# [I 2024-05-23 17:45:03,327] Trial 48 finished with value: 0.8271820687403597 and parameters: {'n_estimators': 87, 'max_depth': 26, 'min_samples_split': 4, 'min_samples_leaf': 18}. Best is trial 40 with value: 0.8492923639538628.
# [I 2024-05-23 17:45:07,698] Trial 49 finished with value: 0.8471845294716523 and parameters: {'n_estimators': 31, 'max_depth': 28, 'min_samples_split': 3, 'min_samples_leaf': 2}. Best is trial 40 with value: 0.8492923639538628.
# Best hyperparameters:  {'n_estimators': 22, 'max_depth': 27, 'min_samples_split': 5, 'min_samples_leaf': 1}
# Test set accuracy:  0.8492708736611175
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.85      7717
#            1       0.87      0.82      0.85      7781
#
#     accuracy                           0.85     15498
#    macro avg       0.85      0.85      0.85     15498
# weighted avg       0.85      0.85      0.85     15498
#
# Confusion Matrix:
#
# [[6794  923]
#  [1413 6368]]

# %%
results_df2 = pd.DataFrame(model_results2)
results_df2
# Out:
#                     Model  Accuracy    Recall  Precision  F1 Score
# 0  tunagem_hyperparametro  0.849271  0.849399   0.850618  0.849157

# %%
joblib.dump(final_pipeline, "/home/felipe/Projeto/Loan_Approval/Arquivos_pickle/model2_hiperparameters.pkl")
# Out:
# ['/home/felipe/Projeto/Loan_Approval/Arquivos_pickle/model2_hiperparameters.pkl']

# %% [markdown]
# ### Subir os dados do resultado do treinamento no banco de dados.

# %%
import sqlalchemy

# %%
engine_mysql = sqlalchemy.create_engine('mysql+pymysql://root:airflow@172.17.0.2:3306/metrics_model')

# %%
# Concatenar os DataFrames
combined_df = pd.concat([results_df, results_df2], ignore_index=True)

# Adicionar a coluna de data atual
combined_df['Date'] = pd.to_datetime('today').normalize()

combined_df
# Out:
#             Scaler                   Model  Accuracy    Recall  Precision  \
# 0             None           Decision Tree  0.550351  0.550161   0.555638
# 1             None     Logistic Regression  0.534348  0.534385   0.534483
# 2             None           Random Forest  0.847228  0.847176   0.849188
# 3             None       Gradient Boosting  0.702542  0.702516   0.702862
# 4             None                LightGBM  0.753323  0.753301   0.753700
# 5             None                 XGBoost  0.774014  0.774022   0.774076
# 6     MaxAbsScaler           Decision Tree  0.550351  0.550161   0.555638
# 7     MaxAbsScaler     Logistic Regression  0.534284  0.534322   0.534428
# 8     MaxAbsScaler           Random Forest  0.847550  0.847499   0.849523
# 9     MaxAbsScaler       Gradient Boosting  0.702499  0.702473   0.702816
# 10    MaxAbsScaler                LightGBM  0.753323  0.753301   0.753700
# 11    MaxAbsScaler                 XGBoost  0.774014  0.774022   0.774076
# 12    MinMaxScaler           Decision Tree  0.550351  0.550161   0.555638
# 13    MinMaxScaler     Logistic Regression  0.534370  0.534408   0.534514
# 14    MinMaxScaler           Random Forest  0.847443  0.847392   0.849387
# 15    MinMaxScaler       Gradient Boosting  0.702456  0.702430   0.702774
# 16    MinMaxScaler                LightGBM  0.752850  0.752831   0.753129
# 17    MinMaxScaler                 XGBoost  0.774014  0.774022   0.774076
# 18      Normalizer           Decision Tree  0.542629  0.542284   0.558703
# 19      Normalizer     Logistic Regression  0.507506  0.506911   0.529204
# 20      Normalizer           Random Forest  0.848540  0.848493   0.850150
# 21      Normalizer       Gradient Boosting  0.731191  0.731148   0.732106
# 22      Normalizer                LightGBM  0.776595  0.776592   0.776623
# 23      Normalizer                 XGBoost  0.789392  0.789397   0.789429
# 24    RobustScaler           Decision Tree  0.550351  0.550161   0.555638
# 25    RobustScaler     Logistic Regression  0.534047  0.534085   0.534190
# 26    RobustScaler           Random Forest  0.847228  0.847176   0.849210
# 27    RobustScaler       Gradient Boosting  0.702499  0.702473   0.702817
# 28    RobustScaler                LightGBM  0.750699  0.750681   0.750895
# 29    RobustScaler                 XGBoost  0.774014  0.774022   0.774076
# 30  StandardScaler           Decision Tree  0.550351  0.550161   0.555638
# 31  StandardScaler     Logistic Regression  0.533961  0.533999   0.534104
# 32  StandardScaler           Random Forest  0.847400  0.847348   0.849398
# 33  StandardScaler       Gradient Boosting  0.702456  0.702430   0.702773
# 34  StandardScaler                LightGBM  0.751151  0.751128   0.751517
# 35  StandardScaler                 XGBoost  0.774014  0.774022   0.774076
# 36             NaN  tunagem_hyperparametro  0.849271  0.849399   0.850618
#
#     F1 Score       Date
# 0   0.539159 2024-05-23
# 1   0.534028 2024-05-23
# 2   0.846998 2024-05-23
# 3   0.702402 2024-05-23
# 4   0.753217 2024-05-23
# 5   0.774005 2024-05-23
# 6   0.539159 2024-05-23
# 7   0.533937 2024-05-23
# 8   0.847320 2024-05-23
# 9   0.702360 2024-05-23
# 10  0.753217 2024-05-23
# 11  0.774005 2024-05-23
# 12  0.539159 2024-05-23
# 13  0.534024 2024-05-23
# 14  0.847216 2024-05-23
# 15  0.702317 2024-05-23
# 16  0.752773 2024-05-23
# 17  0.774005 2024-05-23
# 18  0.509549 2024-05-23
# 19  0.393858 2024-05-23
# 20  0.848353 2024-05-23
# 21  0.730901 2024-05-23
# 22  0.776588 2024-05-23
# 23  0.789387 2024-05-23
# 24  0.539159 2024-05-23
# 25  0.533701 2024-05-23
# 26  0.846996 2024-05-23
# 27  0.702360 2024-05-23
# 28  0.750641 2024-05-23
# 29  0.774005 2024-05-23
# 30  0.539159 2024-05-23
# 31  0.533613 2024-05-23
# 32  0.847166 2024-05-23
# 33  0.702317 2024-05-23
# 34  0.751041 2024-05-23
# 35  0.774005 2024-05-23
# 36  0.849157 2024-05-23

# %%
combined_df.to_sql("metrics_model", engine_mysql, if_exists="replace",index=False)
# Out:
# 37

# %%
cm = confusion_matrix(y_test, y_pred)
cm_df = pd.DataFrame(cm, 
                     index=[f'Actual_{i}' for i in range(cm.shape[0])], 
                     columns=[f'Predicted_{i}' for i in range(cm.shape[1])])
cm_df['Date'] = pd.to_datetime('today').normalize()
cm_df

cm_df.to_sql("confusion_matrix", engine_mysql, if_exists="append",index=False)
# Out:
# 2

# %%
# Gerar Classification Report
report = classification_report(y_test, y_pred, output_dict=True)
report_df = pd.DataFrame(report).transpose()

report_df['Date'] = pd.to_datetime('today').normalize()
report_df.to_sql("classification_report", engine_mysql, if_exists="append",index=False)
report_df
# Out:
#               precision    recall  f1-score       support       Date
# 0              0.827830  0.880394  0.853303   7717.000000 2024-05-23
# 1              0.873406  0.818404  0.845011   7781.000000 2024-05-23
# accuracy       0.849271  0.849271  0.849271      0.849271 2024-05-23
# macro avg      0.850618  0.849399  0.849157  15498.000000 2024-05-23
# weighted avg   0.850712  0.849271  0.849140  15498.000000 2024-05-23
